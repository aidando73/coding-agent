# %%
import matplotlib.pyplot as plt

results = [9, 11.3]
agents = ["OpenHands with Llama 3.1 70B", "Mine with Llama 3.3 70B"]

plt.bar(agents, results, color=['#FF9F7F', '#7FB3FF'])
# plt.bar(agents, results, color=['#FF6B00', '#7FB3FF'])
plt.xlabel('Agents')
plt.ylabel('Pass rate (%)')
plt.title('Pass rate on SWE bench lite')
plt.show()
